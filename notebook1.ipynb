# %%
print("hello")
# Out:
# hello

# %%
# Step 1: Import Libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Step 2: Import Dataset from CSV File
url = "https://raw.githubusercontent.com/rajendra0968jangid/ml-project-1/main/house_data.csv"
df = pd.read_csv(url)
df
# Out:
#    Area  Bedrooms  House_Age    Price
# 0  1200         2         10  2500000
# 1  1500         3          8  3200000
# 2  1800         3          5  4000000
# 3  2000         4          4  4800000
# 4  1700         3          6  3700000
# 5  1400         2         12  2800000
# 6  2200         4          3  5500000
# 7  2500         5          2  6500000
# 8  1900         3          7  4200000
# 9  2100         4          4  5000000

# %%
# Step 3: Define Independent (X) and Dependent (Y)
X = df[['Area', 'Bedrooms', 'House_Age']]
Y = df['Price']

# %%
# Step 4: Split Data into Training and Testing
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,random_state=42)

# %%
# Step 5: Create Model
model = LinearRegression()

# %%
# Step 6: Train Model
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Step 7: Prediction
Y_pred = model.predict(X_test)

print("\nActual Prices:")
print(Y_test.values)

print("\nPredicted Prices:")
print(Y_pred)
# Out:
# Actual Prices:
# [4200000]
#
# Predicted Prices:
# [4375883.87467663]

# %%
# Step 8: Model Evaluation
mae = mean_absolute_error(Y_test,Y_pred)
mse = mean_squared_error(Y_test,Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test,Y_pred)

print("\nModel Evaluation:\n")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R2 Score:", r2)
# Out:
# Model Evaluation:
#
# Mean Absolute Error (MAE): 175883.8746766299
# Mean Squared Error (MSE): 30935137371.264454
# Root Mean Squared Error (RMSE): 175883.8746766299
# R2 Score: nan
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
# Step 9: Predict New House Price
new_house = pd.DataFrame({
    'Area': [2000],
    'Bedrooms': [3],
    'House_Age': [5]
})

predicted_price = model.predict(new_house)

print("\nPredicted Price for New House:")
print(predicted_price[0])
# Out:
# Predicted Price for New House:
# 4616455.878125897
