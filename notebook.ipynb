# %%
print("hello")
# Out:
# hello

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Step 2: Read Data from CSV File
# Import Data set
url = "https://raw.githubusercontent.com/rajendra0968jangid/ml-project-1/main/student_data.csv"
df = pd.read_csv(url)
df
# Out:
#    Attendance  Test_Marks  Assignment_Marks  Practical_Marks  Final_Marks
# 0          85          75                80               78           82
# 1          90          88                85               86           89
# 2          78          65                70               72           68
# 3          92          90                88               91           93
# 4          88          85                84               83           86
# 5          76          60                65               67           63
# 6          95          95                92               94           96
# 7          80          70                75               74           73
# 8          70          55                60               58           59
# 9          89          82                86               84           85

# %%
# # Step 3: Define Input (X) and Output (Y)
X = df[['Attendance','Test_Marks','Assignment_Marks','Practical_Marks']]
Y = df['Final_Marks']
print(X)
print(Y)
# Out:
#    Attendance  Test_Marks  Assignment_Marks  Practical_Marks
# 0          85          75                80               78
# 1          90          88                85               86
# 2          78          65                70               72
# 3          92          90                88               91
# 4          88          85                84               83
# 5          76          60                65               67
# 6          95          95                92               94
# 7          80          70                75               74
# 8          70          55                60               58
# 9          89          82                86               84
# 0    82
# 1    89
# 2    68
# 3    93
# 4    86
# 5    63
# 6    96
# 7    73
# 8    59
# 9    85
# Name: Final_Marks, dtype: int64

# %%
# Step 4: Split Data into Training and Testing
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
print(X_train)
print(X_test)
# Out:
#    Attendance  Test_Marks  Assignment_Marks  Practical_Marks
# 5          76          60                65               67
# 0          85          75                80               78
# 7          80          70                75               74
# 2          78          65                70               72
# 9          89          82                86               84
# 4          88          85                84               83
# 3          92          90                88               91
# 6          95          95                92               94
#    Attendance  Test_Marks  Assignment_Marks  Practical_Marks
# 8          70          55                60               58
# 1          90          88                85               86

# %%
# Step 5: Create Model
model = LinearRegression()

# %%
# Step 6: Train Model
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Step 7: Prediction
Y_pred = model.predict(X_test)

print("\nActual Final Marks:")
print(Y_test.values)

print("\nPredicted Final Marks:")
print(Y_pred)
# Out:
# Actual Final Marks:
# [59 89]
#
# Predicted Final Marks:
# [56.18945039 88.71252189]

# %%
# Step 8: Model Evaluation
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)

print("\nModel Evaluation:\n")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R2 Score:", r2)
# Out:
# Model Evaluation:
#
# Mean Absolute Error (MAE): 1.5490138625518952
# Mean Squared Error (MSE): 3.99091639124295
# Root Mean Squared Error (RMSE): 1.9977278070955888
# R2 Score: 0.982262593816698

# %%
# Step 9: Predict New Student Result
new_student = pd.DataFrame({'Attendance':[87],'Test_Marks':[80],'Assignment_Marks':[82],'Practical_Marks':[23]})
predicted_marks = model.predict(new_student)

print("\nPredicted Final Marks for New Student:")
print(predicted_marks[0])
# Out:
# Predicted Final Marks for New Student:
# 85.0622670616541
